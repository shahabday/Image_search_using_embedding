# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabday/Image_search_using_embedding/blob/main/scratchpad_download_images_from_bing_image_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
from pathlib import Path
import os
path = Path('/gdrive/MyDrive/art_recommendation')
os.makedirs(path , exist_ok=True)
os.listdir(path)
# Out:
# ['diego_rivera',
#  'picasso',
#  'Rivera',
#  'boticelli',
#  'Dali',
#  'pollock',
#  'vangogh',
#  'Yayoi_Kusama',
#  'MF_Husain',
#  'claude_monet',
#  'banksy',
#  'Modigliani',
#  'vermeer',
#  'Tom_Whalen',
#  'Escher',
#  'baldessari',
#  'Giger',
#  'Miro',
#  'Turner',
#  'Kadinsky',
#  'Janco',
#  'hockney',
#  'AI-art',
#  'aryz',
#  'paul_gaugin',
#  'segantini',
#  'Hadid',
#  'Pirosmani',
#  'caravaggio',
#  'G.S. Hunter',
#  'Magritte',
#  'liz_west',
#  'Friedrich Caspar David',
#  'Gotthard Kuehl',
#  'Junjo Ito',
#  'picasso_2',
#  'PJ_Crook',
#  'Gerhard Richter ',
#  'Hans_Hartung',
#  'MC_Escher',
#  'Frida Kahlo',
#  'caravaggio_b36',
#  'Duerer',
#  'Anselm_Feuerbach',
#  'Bouguereau',
#  'Van_Cars10',
#  'kandinsky2',
#  'Leonora Carrington',
#  'oskar_kallis',
#  'Hieronymus_Bosch',
#  'Pieter_Bruegel_the_Elder',
#  'Hiroshige',
#  'Hokusai',
#  'goya',
#  'William_Blake',
#  'Carl Larsson',
#  'toulouse_lautrec',
#  'John_Singer_Sargent (1)',
#  'Balthus',
# ...

# %%
# !pip install bing-image-downloader -q

# %%
from bing_image_downloader import downloader

# %%
artist_name="Edgar_degas"

# %%
folder_path = path / artist_name
os.makedirs(folder_path)

# %%
downloader.download(
                      f'{artist_name} paintings' , limit = 500,
                      output_dir=folder_path,
                      adult_filter_off= True ,
                      force_replace= False ,
                      timeout=60


)
# Out:
# [%] Downloading Images to /gdrive/MyDrive/art_recommendation/Edgar_degas/Edgar_degas paintings
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://3.bp.blogspot.com/-ji3xPOs9IyU/VG8rbjaXIzI/AAAAAAAADmA/mIFg6Ityyp8/s1600/Degas%2BEdgar%2B-%2BDancer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i2.wp.com/www.worldhistory.org/img/c/p/1200x627/15572.png?resize=750
# [!] Issue getting: https://i2.wp.com/www.worldhistory.org/img/c/p/1200x627/15572.png?resize=750
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #2 from https://learnodo-newtonic.com/wp-content/uploads/2015/09/The-Millinery-Shop-1886-Edgar-Degas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.artic.edu/iiif/2/0850f3ab-a29d-acc7-0d3b-0551ceeea5ed/full/1686,/0/default.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://uploads3.wikiart.org/images/edgar-degas/the-green-dancer-1879.jpg
# ...

# %%
downloader.download(
                      f'{artist_name} most famouse painting' , limit = 500,
                      output_dir=folder_path,
                      adult_filter_off= True ,
                      force_replace= False ,
                      timeout=60


)
# Out:
# [%] Downloading Images to /gdrive/MyDrive/art_recommendation/Edgar_degas/Edgar_degas most famouse painting
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://api.brushwiz.com/images/paintings/d/Dancer_Tilting_by_Edgar_Degas_X57.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.judaica-art.com/2665-large_default/ballet-dancer-by-edgar-degas-oil-painting-art-gallery.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://totallyhistory.com/wp-content/uploads/2012/07/two-ballet-dancersby-degas-large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://totallyhistory.com/wp-content/uploads/2012/07/the-dancing-class-by-degas-large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://totallyhistory.com/wp-content/uploads/2012/07/place-de-la-concorde-by-degas-large.jpg
# [%] File Downloaded !
#
# ...

# %%
from pathlib import Path
import shutil
# Define the source and destination directories
source_dir = folder_path
destination_dir = folder_path / 'paintings'
# Create the destination directory if it doesn't exist
destination_dir.mkdir(parents=True, exist_ok=True)
# Iterate through all subdirectories in the source directory
for subdir in source_dir.iterdir():
    if subdir.is_dir():
        # Iterate through all JPG files in each subdirectory
        for file in subdir.glob("*.jpg"):
            # Construct new file name with folder name as prefix
            new_file_name = f"{subdir.name}_{file.name}"
            new_file_path = destination_dir / new_file_name
            # Move and rename each file to the destination directory
            shutil.move(str(file), new_file_path)
